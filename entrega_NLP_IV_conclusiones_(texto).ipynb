# %% [markdown]
# **CONCLUSIONES**
#
# No reiteramos el análisis completo porque la revisión de los modelos se aprecia en los notebooks anteriores. Se aprecia lo siguiente. Abajo se muestran los resultados del segundo modelo (redes neuronales)  contra el primero ( regresión logística) :![Captura de pantalla 2024-03-23 204243.png](data:image/png;base64,...)
#
# ![Captura de pantalla 2024-03-23 204133.png](data:image/png;base64,...)

# %% [markdown]
# Las conclusiones son:
# 1. Ambos modelos tienen resultados parecidos. Ninguno es diferencial sobre el otro.
# 2. Ambos modelos acarrean la misma debilidad resultado de la muestra desbalanceada. Predicen bien el sentimiento positivo pero predicen peor el sentimiento negativo.
# 3. El modelo por redes neuronales es ligeramente peor en la prediccion de sentimientos negativos. Dicho modelo tenía ademas cierto problema de overfitting.
#
# En conclusión se selecciona el modelo de regresión logística ya que, pese a ser un modelo más sencillo, sus prestaciones son ligeramente mejores.
